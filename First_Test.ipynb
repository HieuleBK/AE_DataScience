// %%
%AddJar https://www.dropbox.com/s/9i3vxycay7a37qv/IoTSparkAsServiceSample-3.0.0-jar-with-dependencies.jar?dl=1 -f
%AddJar https://github.com/sathipal/spark-streaming-mqtt-with-security_2.10-1.3.0/releases/download/0.0.1/spark-streaming-mqtt-security_2.10-1.3.0-0.0.1.jar -f
// Out:
// Starting download from https://www.dropbox.com/s/9i3vxycay7a37qv/IoTSparkAsServiceSample-3.0.0-jar-with-dependencies.jar?dl=1
// Finished download of IoTSparkAsServiceSample-3.0.0-jar-with-dependencies.jar
// Starting download from https://github.com/sathipal/spark-streaming-mqtt-with-security_2.10-1.3.0/releases/download/0.0.1/spark-streaming-mqtt-security_2.10-1.3.0-0.0.1.jar
// Finished download of spark-streaming-mqtt-security_2.10-1.3.0-0.0.1.jar

// %%
import com.ibm.iot.iotspark.IoTSparkAsServiceSample

//Watson IoT Platform related parameters
IoTSparkAsServiceSample.setConfig("appid","a:5tetdk:AE_functest")
IoTSparkAsServiceSample.setConfig("uri","ssl://5tetdk.messaging.internetofthings.ibmcloud.com:8883")
IoTSparkAsServiceSample.setConfig("mqtopic","iot-2/type/+/id/+/evt/Bedroom/fmt/+")
IoTSparkAsServiceSample.setConfig("apikey","a-5tetdk-w1dpnruprs")
IoTSparkAsServiceSample.setConfig("authtoken","gWnSd0M@Zo5n6&u-qa")

// %%
// Predictive Service related parameters
IoTSparkAsServiceSample.setConfig("timeMinPredict","1")
//publish-Topic-Name = "this-device" : publish state upto this device
//                     "other" : publish state upto other url or device
//If publish-Topic-Name = "other" then setConfig: serverURI, clientId, apiKey, authToken
IoTSparkAsServiceSample.setConfig("publish-Topic-Name","this-device")
//
//IoTSparkAsServiceSample.setConfig("publish-Topic-Name","iot-2/cmd/PIR_Status/fmt/json")
IoTSparkAsServiceSample.setConfig("predictive-service-url","https://ibm-watson-ml.mybluemix.net/pm/v1/score/leePM?accesskey=iQ1jf2C6ED6NgAYXQae6zKaDADlSjP2Oue2POzYJ1yWDPsJ+t53To+voguCWmnE0HxGxQ3pIogjgEOjN0TGDTcL0h32gVzPkwMbmHXNpi+FQYUqQmv73SQJrb1WXWeZv")

// %%
IoTSparkAsServiceSample.startStreaming(sc, 1)
// Out:
// 	WELCOM TO ART TEAM !!!
// MQTT subscribe topics:iot-2/type/+/id/+/evt/Bedroom/fmt/+
// MQTT uri:ssl://5tetdk.messaging.internetofthings.ibmcloud.com:8883
// MQTT appid:a:5tetdk:AE_functest
// MQTT apikey:a-5tetdk-w1dpnruprs
// MQTT authtoken:gWnSd0M@Zo5n6&u-qa
// Testing the connectivity to Watson IoT Platform ...
// serverURI:ssl://5tetdk.messaging.internetofthings.ibmcloud.com:8883
// clientId:a:5tetdk:AE_functest73
// MQTT Client is connected to the server
// Connected to MQTT server and Kafka
// Able to connect to Watson IoT Platform successfully !!
// +++ print out the received data now:
// org.apache.spark.streaming.api.java.JavaReceiverInputDStream@99199c96
// +++ GOOD:
// -------------------------------------------
// Time: 1498554043000 ms
// -------------------------------------------
//
// -------------------------------------------
// Time: 1498554044000 ms
// -------------------------------------------
//
// -------------------------------------------
// ...
